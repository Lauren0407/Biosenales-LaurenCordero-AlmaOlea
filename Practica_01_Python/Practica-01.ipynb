# %% [markdown]
# # Práctica 1 - Lab Bioseñales
#
# Lauren Cordero y Alma Olea

# %% [markdown]
# ## Punto 1
#
# a) Crear el par de vectores

# %%
a = [3.1, 1, -0.5, -3.2, 6] 
b = [1, 3, 2.2, 5.1, 1]

# %%
print(a,b)
# Out:
# [3.1, 1, -0.5, -3.2, 6] [1, 3, 2.2, 5.1, 1]
